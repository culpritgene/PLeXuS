# %%
from imports import *
from utils import *
from BackEndGame import *
from FrontEndGame import *
# Out:
# 	:: Module `pygraphviz` not available.
# 	   You don't need it unless you want to export dot files.
# 	:: No MySQL support.
# 	:: No MySQL support.
#
# 	:: Module `pysftp` not available.
#         Only downloading of a small number of resources
#         relies on this module.
#         Please install by PIP if it is necessary for you.
#     	:: Module `fabric` not available.
# /home/moonstrider/anaconda3/envs/iDS/lib/python3.6/site-packages/matplotlib/backends/tkagg.py:10: MatplotlibDeprecationWarning:
# The matplotlib.backends.tkagg module is deprecated.
#   "3.0", "The matplotlib.backends.tkagg module is deprecated.")
# 	:: Module `hcluster` not available.

# %%
pa = pickle.load(open('Resources/Network_pypath_burn.by', 'br'))

# %%
root=tk.Tk()
gui=Gui(root, pa)
root.mainloop()
# Out:
# /home/moonstrider/PycharmProjects/DrawBio-v0.1/BackEndGame.py:83: RuntimeWarning: Couldn't reach some vertices at structural_properties.c:740
#   self.parent.current_game_network_filt.get_shortest_paths(cuid))  ### get farthest points in current subgraph
# 1
# /home/moonstrider/PycharmProjects/DrawBio-v0.1/BackEndGame.py:120: RuntimeWarning: Couldn't reach some vertices at structural_properties.c:740
#   self.all_paths = self.net.get_shortest_paths(ind)
# 2983 all unconnected partners
# New-edge: GNAI3 ---> CBLN2 False
# New-edge: GNAI3 ---> TFF3 False
# New-edge: GNAI3 ---> TSHR Correct
# 1
# 2983 all unconnected partners
# New-edge: GNAI3 ---> TRAC False
# New-edge: GNAI3 ---> INTS11 False
# New-edge: GNAI3 ---> TSHR Correct
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/moonstrider/anaconda3/envs/iDS/lib/python3.6/tkinter/__init__.py", line 1705, in __call__
#     return self.func(*args)
# ...

# %%
gui.STATS.
# Out:
#            Pos  Neg   Score
# ARAF       0.0  0.0  0.0000
# BMF        0.0  0.0  0.0000
# ITCH       0.0  0.0  0.0000
# ASCC3      0.0  0.0  0.0000
# TFAM       0.0  0.0  0.0000
# CDKN1C     0.0  0.0  0.0000
# UBE2T      0.0  0.0  0.0000
# PMS2       0.0  0.0  0.0000
# RALBP1     0.0  0.0  0.0000
# NQO1       0.0  0.0  0.0000
# SLC38A2    0.0  0.0  0.0000
# DHX9       0.0  0.0  0.0000
# WNT4       0.0  0.0  0.0000
# RCHY1      0.0  0.0  0.0000
# TRRAP      0.0  0.0  0.0000
# HNRNPU     0.0  0.0  0.0000
# XPA        0.0  0.0  0.0000
# KDM4A      0.0  0.0  0.0000
# LTBR       0.0  0.0  0.0000
# ABRAXAS1   0.0  0.0  0.0000
# CHD4       0.0  0.0  0.0000
# SLC6A12    0.0  0.0  0.0000
# CHAMP1     0.0  0.0  0.0000
# ENTPD1     0.0  0.0  0.0000
# DYNLL2     0.0  0.0  0.0000
# DKK1       0.0  0.0  0.0000
# MBD2       0.0  0.0  0.0000
# IRF1       0.0  0.0  0.0000
# TNFRSF10D  0.0  0.0  0.0000
# ELAVL1     1.0  2.0  0.1519
# ...        ...  ...     ...
# PNLIPRP2   0.0  0.0  0.0000
# ...

# %%
gui.CUR_DB.get(), gui.CUR_PATHWAY.get(), list(gui.PATHWAY_LIST)[:3], gui.CUR_F_NODE.get(), gui.CUR_NODES
# Out:
# ('kegg',
#  'Mitophagy - animal',
#  ['Ras signaling pathway', 'Rap1 signaling pathway', 'MAPK signaling pathway'],
#  'NaN',
#  ['MEIS2',
#   'TP53',
#   'PINK1',
#   'BNIP3',
#   'AMBRA1',
#   'RAB7A',
#   'NAP1L1',
#   'HIF1A',
#   'SQSTM1',
#   'SETD2',
#   'ULK1',
#   'CSNK2A1',
#   'SP1',
#   'FOXO3',
#   'SRC',
#   'ATF4',
#   'NBR1',
#   'BNIP3L',
#   'ATF2',
#   'PRKN',
#   'MAPK8',
#   'NCOA1',
#   'BCL2L1',
#   'GABARAP',
#   'E2F1',
#   'EIF2AK3',
#   'RELA',
#   'ATG5',
#   'JUN',
#   'TBK1',
#   'WARS',
#   'TAX1BP1',
#   'MFN2',
#   'CALCOCO2',
#   'OPTN',
#   'RRAS2',
#   'RHOT1',
#   'MFN1',
#   'PGAM5',
#   'NRP1',
#   'ASIP',
#   'USP8',
#   'FUNDC1',
#   'FIS1',
#   'RAB7B',
#   'TBC1D15',
#   'UBB',
#   'A1CF',
#   'TOMM7',
#   'CITED2',
#   'BCL2L13',
#   'CSNK2A3',
#   'ROPN1L',
#   'BECN2',
#   'RBP3'])

# %%
for i,g in enumerate([1,2,3]):
    print(i,g)
# Out:
# 0 1
# 1 2
# 2 3

# %%
gui.prot_names['kegg']
# Out:
# {'Ras signaling pathway': ['Q86WH2',
#   'Q13043',
#   'P42336',
#   'P15976',
#   'P98177',
#   'Q04864',
#   'O43561',
#   'Q9NRY4',
#   'P98077',
#   'Q8WWW0',
#   'Q13972',
#   'P55196',
#   'P14921',
#   'Q9UHD2',
#   'P60953',
#   'P26927',
#   'P21359',
#   'Q06124',
#   'P43403',
#   'Q02750',
#   'Q9NYB0',
#   'Q13393',
#   'O15111',
#   'O15211',
#   'Q6VAB6',
#   'P09603',
#   'Q13671',
#   'O14807',
#   'O14775',
#   'Q92565',
#   'P11233',
#   'Q9P212',
#   'P28482',
#   'P00519',
#   'P10301',
#   'P17612',
#   'O96013',
#   'P63000',
#   'Q9Y6Y0',
#   'P04049',
#   'P0C869',
#   'P01111',
#   'Q9NS23',
#   'P34969',
#   'P14210',
#   'Q92934',
#   'P19419',
#   'Q96KP1',
#   'Q15311',
#   'Q01650',
#   'P01112',
#   'P45983',
#   'C9J798',
#   'P61586',
#   'P01116',
#   'Q13480',
#   'P62993',
#   'Q13009',
#   'P19174',
#   'P62834',
#   'P62070',
#   'Q06520',
#   'P19838',
#   'Q9Y243',
#   'Q12967',
#   'Q13546',
#   'P29323',
#   'Q7LDG7',
#   'Q7Z569',
# ...

# %%
gui.CUR_PATHWAY.get()
# Out:
# 'NF-kappa B signaling pathway'

# %%
gui.CUR_NODES
# Out:
# ['IKBKB',
#  'CHUK',
#  'NFKBIA',
#  'TRAF2',
#  'MAP3K7',
#  'CSNK2A1',
#  'TRAF6',
#  'NFKB1',
#  'RIPK1',
#  'PLCG1',
#  'SYK']

# %%
gui.current_labirinth_game.game_subgraph.vs()[0]
# Out:
# igraph.Vertex(<igraph.Graph object at 0x7f389f47d7c8>, 0, {'type': 'protein', 'nameType': 'uniprot', 'originalNames': {'TLR4': 'genesymbol', 'O00206': 'uniprot'}, 'ncbi_tax_id': 9606, 'exp': None, 'sources': {'SPIKE', 'Macrophage', 'BioGRID', 'HPMR', 'SignaLink3', 'InnateDB', 'IntAct', 'HPRD', 'Signor', 'PhosphoSite', 'Ramilowski2015', 'MatrixDB'}, 'references': {<pypath.refs.Reference object at 0x7f38a5672108>, <pypath.refs.Reference object at 0x7f38a5672468>, <pypath.refs.Reference object at 0x7f38a64e86d8>, <pypath.refs.Reference object at 0x7f38a5672408>, <pypath.refs.Reference object at 0x7f38a56e9dc8>, <pypath.refs.Reference object at 0x7f38a5672978>, <pypath.refs.Reference object at 0x7f38a56726a8>, <pypath.refs.Reference object at 0x7f38a56e9e58>, <pypath.refs.Reference object at 0x7f38a56724c8>, <pypath.refs.Reference object at 0x7f38a5c67828>, <pypath.refs.Reference object at 0x7f38a5672858>, <pypath.refs.Reference object at 0x7f38a5672318>, <pypath.refs.Reference object at
# ...

# %%
js.dump(gui.current_labirinth_game.game_subgraph, 'TEST_SUBGRAPH.json')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-5244da0bd3ea> in <module>
# ----> 1 js.dump(gui.current_labirinth_game.game_subgraph, 'TEST_SUBGRAPH.json')
#
# ~/anaconda3/envs/iDS/lib/python3.6/json/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# ~/anaconda3/envs/iDS/lib/python3.6/json/encoder.py in _iterencode(o, _current_indent_level)
#     435                     raise ValueError("Circular reference detected")
#     436                 markers[markerid] = o
# --> 437             o = _default(o)
#     438             yield from _iterencode(o, _current_indent_level)
# ...

# %%
for e in gui.current_labirinth_game.game_subgraph.es():
    print(e.tuple)
# Out:
# (0, 1)
# (0, 2)
# (0, 3)

# %%
gui.init_network_filt.vs()[[2, 27, 31, 98, 122]]['label']

# %%
# Out:
# [2,
#  27,
#  31,
#  98,
#  122,
#  126,
#  157,
#  174,
#  198,
#  207,
#  230,
#  265,
#  326,
#  343,
#  350,
#  353,
#  361,
#  377,
#  379,
#  380,
#  391,
#  408,
#  440]
